# %% [markdown]
# The goal of this notebook is to show how to use the deployed model:

# %%
from helpers import final_model_helper
import importlib

# %% [markdown]
# # Data preprocessing
#
# Since there is more than one table, the first needs to be aggregated. I assume, that it is easier to preprocess the tables locally rather than uploading whole tables to cloud. If this was an actual database solution, the tables would be naturally integrated.
#
# This can be done using just few commands with the provided aggregator.

# %%
importlib.reload(final_model_helper)
prep = final_model_helper.tables_to_input_converters("data/raw_csv", "models")

# %%
prep.nb1_get_application_table().head()
# Out:
# Loading tables: ['application_train.csv']
# loaded application_train with shape (307511, 122)
# No missing columns.
# Unexpected columns: ['SK_ID_CURR']
# No missing columns.
# Unexpected columns: ['SK_ID_CURR']
# Loading tables: ['application_test.csv']
# loaded application_test with shape (48744, 121)
# No missing columns.
# Unexpected columns: ['SK_ID_CURR']
# No missing columns.
# Unexpected columns: ['SK_ID_CURR']
# Warning: Column 'TARGET' contains NaN values. These will become False.
# No missing columns.
# Unexpected columns: ['SK_ID_CURR']
#        SK_ID_CURR  ...  AMT_REQ_CREDIT_BUREAU_YEAR
# 0          100002  ...                         1.0
# 1          100003  ...                         0.0
# 2          100004  ...                         0.0
# 3          100006  ...                         NaN
# 4          100007  ...                         0.0
# ...           ...  ...                         ...
# 356250     456221  ...                         1.0
# 356251     456222  ...                         NaN
# 356252     456223  ...                         1.0
# 356253     456224  ...                         2.0
# 356254     456250  ...                         4.0
#
# [356255 rows x 122 columns]

# %%
prep.nb5_bureau_balance_agg().head()
# Out:
# Loading tables: ['bureau_balance.csv']
# loaded bureau_balance with shape (27299925, 3)
# dict_keys(['credit_status', 'bureau_overdue', 'time_variables', 'bureau', 'bureau_balance', 'pos_cash_balance', 'balance_limits', 'drawings_payments', 'contract_installments', 'credit_card_balance', 'previous_application', 'installments_payments'])
# No missing columns.
# Unexpected columns: ['SK_ID_BUREAU']
# No missing columns.
# Unexpected columns: ['SK_ID_BUREAU']
# No missing columns.
# Unexpected columns: ['SK_ID_BUREAU']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 prep.nb5_bureau_balance_agg().head()
#
# File c:\GITHUB\Turing submissions\psauci-DS.v2.5.3.4.1\helpers\final_model_helper.py:174, in tables_to_input_converters.nb5_bureau_balance_agg(self)
#     169     agg_bureau_balance["bad_payments"] = (
#     170         agg_bureau_balance["bad_payments"].fillna(0).astype(int)
#     171     )
#     172     return agg_bureau_balance
# --> 174 agg_balance = include_bad_payments(balance, agg_df)
#     176 return agg_balance
#
# File c:\GITHUB\Turing submissions\psauci-DS.v2.5.3.4.1\helpers\final_model_helper.py:167, in tables_to_input_converters.nb5_bureau_balance_agg.<locals>.include_bad_payments(balance, agg_df)
#     155 bad_payments = (
#     156     bad_payments.groupby("SK_ID_BUREAU")
#     157     .size()
#     158     .reset_index(name="bad_payments")
#     159 )
#     161 agg_bureau_balance = pd.merge(
#     162     agg_df,
#     163     bad_payments,
#     164     on="SK_ID_BUREAU",
#     165     how="outer",
#     166 )
# --> 167 agg_bureau_balance = bad_payments(balance, agg_df)
#     169 agg_bureau_balance["bad_payments"] = (
#     170     agg_bureau_balance["bad_payments"].fillna(0).astype(int)
#     171 )
#     172 return agg_bureau_balance
#
# TypeError: 'DataFrame' object is not callable

# %%
prep.nb6_bureau_agg().head()
# Out:
# Loading tables: ['bureau.csv']
# loaded bureau with shape (1716428, 17)
# dict_keys(['credit_status', 'bureau_overdue', 'time_variables', 'bureau', 'bureau_balance', 'pos_cash_balance', 'balance_limits', 'drawings_payments', 'contract_installments', 'credit_card_balance', 'previous_application', 'installments_payments'])
# No missing columns.
# Unexpected columns: ['SK_ID_CURR', 'SK_ID_BUREAU']
# No missing columns.
# Unexpected columns: ['SK_ID_CURR', 'SK_ID_BUREAU']
# No missing columns.
# Unexpected columns: ['SK_ID_CURR', 'SK_ID_BUREAU']
# Loading tables: ['bureau_balance.csv']
# loaded bureau_balance with shape (27299925, 3)
# dict_keys(['credit_status', 'bureau_overdue', 'time_variables', 'bureau', 'bureau_balance', 'pos_cash_balance', 'balance_limits', 'drawings_payments', 'contract_installments', 'credit_card_balance', 'previous_application', 'installments_payments'])
# No missing columns.
# Unexpected columns: ['SK_ID_BUREAU']
# No missing columns.
# Unexpected columns: ['SK_ID_BUREAU']
# No missing columns.
# Unexpected columns: ['SK_ID_BUREAU']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 prep.nb6_bureau_agg()
#
# File c:\GITHUB\Turing submissions\psauci-DS.v2.5.3.4.1\helpers\final_model_helper.py:201, in tables_to_input_converters.nb6_bureau_agg(self)
#     198 metrics_dict["bur_bal_bad_payments"] = ["sum", "max", "median" "min", "std"]
#     199 metrics_dict["bur_bal_f_0"] = ["onehot_count"]
# --> 201 balance_df = self.nb5_bureau_balance_agg()
#     203 bureau_df = pd.merge(bureau_df, balance_df, on="SK_ID_BUREAU", how="left")
#     204 agg = aggregator_helper.RowAggregator(
#     205     bureau_df,
#     206     stack_columns=["SK_ID_CURR", "CREDIT_ACTIVE"],
#     207     agg_dict=metrics_dict,
#     208 )
#
# File c:\GITHUB\Turing submissions\psauci-DS.v2.5.3.4.1\helpers\final_model_helper.py:174, in tables_to_input_converters.nb5_bureau_balance_agg(self)
#     169     agg_bureau_balance["bad_payments"] = (
#     170         agg_bureau_balance["bad_payments"].fillna(0).astype(int)
#     171     )
#     172     return agg_bureau_balance
# --> 174 agg_balance = include_bad_payments(balance, agg_df)
#     176 return agg_balance
#
# File c:\GITHUB\Turing submissions\psauci-DS.v2.5.3.4.1\helpers\final_model_helper.py:167, in tables_to_input_converters.nb5_bureau_balance_agg.<locals>.include_bad_payments(balance, agg_df)
#     155 bad_payments = (
#     156     bad_payments.groupby("SK_ID_BUREAU")
#     157     .size()
#     158     .reset_index(name="bad_payments")
#     159 )
#     161 agg_bureau_balance = pd.merge(
#     162     agg_df,
#     163     bad_payments,
#     164     on="SK_ID_BUREAU",
#     165     how="outer",
#     166 )
# --> 167 agg_bureau_balance = bad_payments(balance, agg_df)
#     169 agg_bureau_balance["bad_payments"] = (
#     170     agg_bureau_balance["bad_payments"].fillna(0).astype(int)
#     171 )
#     172 return agg_bureau_balance
#
# TypeError: 'DataFrame' object is not callable
